# %% [markdown]
# # Notebook 01 - Data Extraction
# loading the raw csv and checking what we are working with

# %%
import pandas as pd
import numpy as np
import json

# %%
df = pd.read_csv('../data/raw/nyc_parking_tickets_sample.csv', dtype=str)
df.columns = df.columns.str.replace(' ', '_')
print("rows:", df.shape[0])
print("columns:", df.shape[1])
# Out:
# rows: 12000
# columns: 14

# %% [markdown]
# checking how many nulls each column has

# %%
null_report = pd.DataFrame({
    'null_count': df.isnull().sum(),
    'null_pct': (df.isnull().sum() / len(df) * 100).round(2)
})
print(null_report[null_report.null_count > 0])
# Out:
#                     null_count  null_pct
# Plate_ID                   343      2.86
# Registration_State         263      2.19
# Plate_Type                 363      3.02
# Issue_Date                 366      3.05
# Vehicle_Body_Type          478      3.98
# Vehicle_Make               474      3.95
# Vehicle_Color              605      5.04
# Vehicle_Year               496      4.13
# Street_Name                370      3.08
# Violation_County           512      4.27
# Fine_Amount                457      3.81

# %% [markdown]
# looking at unique values in each column to understand the data better

# %%
for col in df.columns:
    print(col, "->", df[col].nunique(), "unique values")
    print("   sample:", list(df[col].dropna().unique()[:4]))
    print()
# Out:
# Summons_Number -> 12000 unique values
#    sample: ['5954207902', '7157381638', '3592473405', '5627932902']
#
# Plate_ID -> 11656 unique values
#    sample: ['DGB1271', 'JWE2043', 'LDL3141', 'FRM0430']
#
# Registration_State -> 29 unique values
#    sample: ['NJ', 'NY', 'CT', 'IL']
#
# Plate_Type -> 16 unique values
#    sample: ['PAS', 'OMS', 'COM', 'OMT']
#
# Issue_Date -> 642 unique values
#    sample: ['05/24/2014', '08/27/2013', '07/13/2013', '11/18/2013']
#
# Violation_Code -> 13 unique values
#    sample: ['38', '21', '40', '37']
#
# Vehicle_Body_Type -> 20 unique values
#    sample: ['van', 'PICK', 'SUV', 'SDN']
#
# Vehicle_Make -> 40 unique values
#    sample: ['HYUNDAI', 'BMW', 'TOYOTA', 'KIA']
#
# Vehicle_Color -> 25 unique values
#    sample: ['BROWN', 'ORANGE', 'white', 'BLACK']
#
# Vehicle_Year -> 18 unique values
#    sample: ['2003', '2009', '2000', '2006']
#
# Violation_Description -> 13 unique values
#    sample: ['Failure to Display Muni Meter Receipt', 'No Parking - Street Cleaning', 'Fire Hydrant', 'Expired Muni Meter']
#
# Street_Name -> 34 unique values
#    sample: ['NOSTRAND AVE', 'JAMAICA AVE', 'PARK AVE', 'ATLANTIC AVE']
#
# Violation_County -> 10 unique values
#    sample: ['Brooklyn', 'Staten Island', 'Queens', 'Manhattan']
#
# Fine_Amount -> 5 unique values
#    sample: ['65', '115', '-65', '0']

# %% [markdown]
# saving this audit so we can reference it later in the report

# %%
audit = {
    "total_rows": int(df.shape[0]),
    "total_cols": int(df.shape[1]),
    "columns": list(df.columns),
    "null_counts": df.isnull().sum().to_dict()
}
with open('../docs/cleaning_audit.json', 'w') as f:
    json.dump(audit, f, indent=2)
print("audit saved")
# Out:
# audit saved
